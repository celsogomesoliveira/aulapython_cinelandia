# %%
# Out:
#   Cell In[55], line 1
#     . gitignore.csv
#     ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding='latin1')
df
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36898   159   10  2025  2025m10    35     4  Cachoeiras de Macacu  3300803
# 36899   165   10  2025  2025m10    33     5           Mangaratiba  3302601
# 36900   166   10  2025  2025m10    33     5        Angra dos Reis  3300100
# 36901   167   10  2025  2025m10    43     5                Paraty  3303807
# 36902   168   10  2025  2025m10    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...   NaN   NaN      21                      2
# 1       Capital           3  ...   NaN   NaN      15                      6
# 2       Capital           3  ...   NaN   NaN      47                      2
# 3       Capital           6  ...   NaN   NaN      26                      2
# 4       Capital           4  ...   NaN   NaN      10                      1
# ...         ...         ...  ...   ...   ...     ...                    ...
# 36898  Interior           1  ...   4.0   0.0      37                      2
# 36899  Interior           1  ...   4.0   0.0      21                      0
# 36900  Interior           3  ...  12.0   0.0      82                      8
# 36901  Interior           1  ...   2.0   1.0      11                      1
# 36902  Interior           0  ...   0.0   0.0       3                      1
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 36898                 0                0                          0
# 36899                 0                0                          0
# 36900                 0                1                          0
# 36901                 0                0                          0
# 36902                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 36898                      0                   163     2
# 36899                      0                   196     2
# 36900                      0                   682     2
# 36901                      0                   195     2
# 36902                      0                    66     2
#
# [36903 rows x 63 columns]

# %%
df_furto_celular_dp = df.groupby('cisp')['furto_celular'].sum().reset_index()
df_furto_celular_dp =  df_furto_celular_dp.sort_values(by='furto_celular', ascending=False)
df_furto_celular_dp
# Out:
#      cisp  furto_celular
# 12     16          24879
# 2       5          23117
# 10     14          16945
# 8      12          16008
# 0       1          14968
# ..    ...            ...
# 87    104             72
# 77     92             63
# 131   157             55
# 114   138             52
# 129   155             47
#
# [138 rows x 2 columns]

# %%
array_furto_celular_dp = np.array(df_furto_celular_dp['furto_celular'])

# %%
media = np.mean(array_furto_celular_dp)
mediana = np.median(array_furto_celular_dp)
q1 = np.quantile(array_furto_celular_dp, 0.25)
q2 = np.quantile(array_furto_celular_dp, 0.50)
q3 = np.quantile(array_furto_celular_dp, 0.75)

print("A média é " +str(media))
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
#Distância = (média - mediana) / mediana
distancia = ((media - mediana)/mediana)
distanciaDEC = (distancia)*100
print(f"A distância é {distanciaDEC}")
# Out:
# A média é 3338.1159420289855
# A mediana é 1633.5
# Primeiro quartil (Q1): 449.0
# Segundo quartil (Q2, Mediana): 1633.5
# Terceiro quartil (Q3): 4498.25
# A distância é 104.35359302289473

# %%
dfM = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep= ';', encoding='latin1')
dfM
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0       3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1       3300159             Aperibé  2014    1  2014m01  Interior           0
# 2       3300209            Araruama  2014    1  2014m01  Interior           2
# 3       3300225               Areal  2014    1  2014m01  Interior           0
# 4       3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
# ...         ...                 ...   ...  ...      ...       ...         ...
# 13060   3306008           Três Rios  2025   10  2025m10  Interior           3
# 13061   3306107             Valença  2025   10  2025m10  Interior           0
# 13062   3306156           Varre-Sai  2025   10  2025m10  Interior           0
# 13063   3306206           Vassouras  2025   10  2025m10  Interior           1
# 13064   3306305       Volta Redonda  2025   10  2025m10  Interior           8
#
#        lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                     0           0    11  ...    8     0      98
# 1                     0           0     0  ...    0     0       0
# 2                     0           0     2  ...    5     0      91
# 3                     0           0     0  ...    0     0       0
# 4                     0           0     2  ...    3     2      46
# ...                 ...         ...   ...  ...  ...   ...     ...
# 13060                 0           0     3  ...   22     0      68
# 13061                 0           0     0  ...    8     3      31
# 13062                 0           0     0  ...    1     0       5
# 13063                 0           0     1  ...    1     0      15
# 13064                 0           0     8  ...   23     0     142
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                         13                 3                0
# 1                          0                 0                0
# 2                         10                 1                0
# 3                          0                 0                0
# 4                          0                 0                0
# ...                      ...               ...              ...
# 13060                      3                 0                0
# 13061                      3                 1                0
# 13062                      0                 0                0
# 13063                      2                 0                0
# 13064                      7                 1                1
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                              0                      0                   561
# 1                              0                      0                     0
# 2                              0                      0                   480
# 3                              0                      0                     0
# 4                              0                      0                   309
# ...                          ...                    ...                   ...
# 13060                          0                      0                   536
# 13061                          0                      0                   227
# 13062                          0                      0                    20
# 13063                          0                      0                   139
# 13064                          0                      0                  1482
#
#        fase
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 13060     2
# 13061     2
# 13062     2
# 13063     2
# 13064     2
#
# [13065 rows x 60 columns]

# %%
dfM = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep= ';', encoding='latin1')
dfM
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0       3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1       3300159             Aperibé  2014    1  2014m01  Interior           0
# 2       3300209            Araruama  2014    1  2014m01  Interior           2
# 3       3300225               Areal  2014    1  2014m01  Interior           0
# 4       3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
# ...         ...                 ...   ...  ...      ...       ...         ...
# 13060   3306008           Três Rios  2025   10  2025m10  Interior           3
# 13061   3306107             Valença  2025   10  2025m10  Interior           0
# 13062   3306156           Varre-Sai  2025   10  2025m10  Interior           0
# 13063   3306206           Vassouras  2025   10  2025m10  Interior           1
# 13064   3306305       Volta Redonda  2025   10  2025m10  Interior           8
#
#        lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                     0           0    11  ...    8     0      98
# 1                     0           0     0  ...    0     0       0
# 2                     0           0     2  ...    5     0      91
# 3                     0           0     0  ...    0     0       0
# 4                     0           0     2  ...    3     2      46
# ...                 ...         ...   ...  ...  ...   ...     ...
# 13060                 0           0     3  ...   22     0      68
# 13061                 0           0     0  ...    8     3      31
# 13062                 0           0     0  ...    1     0       5
# 13063                 0           0     1  ...    1     0      15
# 13064                 0           0     8  ...   23     0     142
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                         13                 3                0
# 1                          0                 0                0
# 2                         10                 1                0
# 3                          0                 0                0
# 4                          0                 0                0
# ...                      ...               ...              ...
# 13060                      3                 0                0
# 13061                      3                 1                0
# 13062                      0                 0                0
# 13063                      2                 0                0
# 13064                      7                 1                1
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                              0                      0                   561
# 1                              0                      0                     0
# 2                              0                      0                   480
# 3                              0                      0                     0
# 4                              0                      0                   309
# ...                          ...                    ...                   ...
# 13060                          0                      0                   536
# 13061                          0                      0                   227
# 13062                          0                      0                    20
# 13063                          0                      0                   139
# 13064                          0                      0                  1482
#
#        fase
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 13060     2
# 13061     2
# 13062     2
# 13063     2
# 13064     2
#
# [13065 rows x 60 columns]

# %%
df_furto_celular_dp = df.groupby('cisp')['furto_celular'].sum().reset_index()
df_furto_celular_dp =  df_furto_celular_dp.sort_values(by='furto_celular', ascending=False)
df_furto_celular_dp
# Out:
#      cisp  furto_celular
# 12     16          24879
# 2       5          23117
# 10     14          16945
# 8      12          16008
# 0       1          14968
# ..    ...            ...
# 87    104             72
# 77     92             63
# 131   157             55
# 114   138             52
# 129   155             47
#
# [138 rows x 2 columns]

# %%
array_furto_celular_dp = np.array(df_furto_celular_dp['furto_celular'])

# %%
media = np.mean(array_furto_celular_dp)
mediana = np.median(array_furto_celular_dp)
q1 = np.quantile(array_furto_celular_dp, 0.25)
q2 = np.quantile(array_furto_celular_dp, 0.50)
q3 = np.quantile(array_furto_celular_dp, 0.75)
#Distância = (média - mediana) / mediana
distancia = ((media - mediana)/mediana)
distanciaDEC = (distancia)*100
iqr = q3 - q1
limite_superior = q3 + 1.5 * iqr
limite_inferior = q1 - 1.5 * iqr

print("A média é " +str(media))
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')

print(f"A distância é {distanciaDEC}")
print(f'O IQR é {iqr}')
print(f'O limite superior é {limite_superior}')
print(f'O limite inferior é {limite_inferior}') 
# quando o limite inferior for negativo, considerar como nao tendo outlier inferior
# Out:
# A média é 3338.1159420289855
# A mediana é 1633.5
# Primeiro quartil (Q1): 449.0
# Segundo quartil (Q2, Mediana): 1633.5
# Terceiro quartil (Q3): 4498.25
# A distância é 104.35359302289473
# O IQR é 4049.25
# O limite superior é 10572.125
# O limite inferior é -5624.875

# %%
outliers_furto_celular_dp = df_furto_celular_dp.loc[(df_furto_celular_dp['furto_celular'] > limite_superior) | (df_furto_celular_dp['furto_celular'] < limite_inferior)]
outliers_furto_celular_dp
# Out:
#     cisp  furto_celular
# 12    16          24879
# 2      5          23117
# 10    14          16945
# 8     12          16008
# 0      1          14968
# 5      9          14159
# 6     10          14105
# 1      4          13318
# 14    18          12939
# 28    32          12206
# 31    35          11824

# %%
dfM = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseMunicipioMensal.csv', sep= ';', encoding='latin1')
dfM
# Out:
#        fmun_cod                fmun   ano  mes  mes_ano    regiao  hom_doloso  \
# 0       3300100      Angra dos Reis  2014    1  2014m01  Interior          11
# 1       3300159             Aperibé  2014    1  2014m01  Interior           0
# 2       3300209            Araruama  2014    1  2014m01  Interior           2
# 3       3300225               Areal  2014    1  2014m01  Interior           0
# 4       3300233  Armação dos Búzios  2014    1  2014m01  Interior           2
# ...         ...                 ...   ...  ...      ...       ...         ...
# 13060   3306008           Três Rios  2025   10  2025m10  Interior           3
# 13061   3306107             Valença  2025   10  2025m10  Interior           0
# 13062   3306156           Varre-Sai  2025   10  2025m10  Interior           0
# 13063   3306206           Vassouras  2025   10  2025m10  Interior           1
# 13064   3306305       Volta Redonda  2025   10  2025m10  Interior           8
#
#        lesao_corp_morte  latrocinio  cvli  ...  cmp  cmba  ameaca  \
# 0                     0           0    11  ...    8     0      98
# 1                     0           0     0  ...    0     0       0
# 2                     0           0     2  ...    5     0      91
# 3                     0           0     0  ...    0     0       0
# 4                     0           0     2  ...    3     2      46
# ...                 ...         ...   ...  ...  ...   ...     ...
# 13060                 0           0     3  ...   22     0      68
# 13061                 0           0     0  ...    8     3      31
# 13062                 0           0     0  ...    1     0       5
# 13063                 0           0     1  ...    1     0      15
# 13064                 0           0     8  ...   23     0     142
#
#        pessoas_desaparecidas  encontro_cadaver  encontro_ossada  \
# 0                         13                 3                0
# 1                          0                 0                0
# 2                         10                 1                0
# 3                          0                 0                0
# 4                          0                 0                0
# ...                      ...               ...              ...
# 13060                      3                 0                0
# 13061                      3                 1                0
# 13062                      0                 0                0
# 13063                      2                 0                0
# 13064                      7                 1                1
#
#        pol_militares_mortos_serv  pol_civis_mortos_serv  registro_ocorrencias  \
# 0                              0                      0                   561
# 1                              0                      0                     0
# 2                              0                      0                   480
# 3                              0                      0                     0
# 4                              0                      0                   309
# ...                          ...                    ...                   ...
# 13060                          0                      0                   536
# 13061                          0                      0                   227
# 13062                          0                      0                    20
# 13063                          0                      0                   139
# 13064                          0                      0                  1482
#
#        fase
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
# ...     ...
# 13060     2
# 13061     2
# 13062     2
# 13063     2
# 13064     2
#
# [13065 rows x 60 columns]

# %%
df_estelionato_dp = dfM.groupby('fmun')['estelionato'].sum().reset_index()
df_estelionato_dp =  df_estelionato_dp.sort_values(by='estelionato', ascending=False)
df_estelionato_dp
# Out:
#                      fmun  estelionato
# 67         Rio de Janeiro       459529
# 47                Niterói        38230
# 24        Duque de Caxias        29747
# 49            Nova Iguaçu        28700
# 77            São Gonçalo        28425
# ..                    ...          ...
# 35         Laje do Muriaé          126
# 16              Carapebus          124
# 89              Varre-Sai          102
# 83  São Sebastião do Alto          100
# 78        São José de Ubá           60
#
# [92 rows x 2 columns]

# %%
array_df_estelionato_dp = np.array(df_estelionato_dp['estelionato'])

# %%
media = np.mean(array_df_estelionato_dp)
mediana = np.median(array_df_estelionato_dp)
q1 = np.quantile(array_df_estelionato_dp, 0.25)
q2 = np.quantile(array_df_estelionato_dp, 0.50)
q3 = np.quantile(array_df_estelionato_dp, 0.75)

print("A média é " +str(media))
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
#Distância = (média - mediana) / mediana
distancia = ((media - mediana)/mediana)
distanciaDEC = (distancia)*100
print(f"A distância é {distanciaDEC}")
# Out:
# A média é 9197.141304347826
# A mediana é 1100.0
# Primeiro quartil (Q1): 398.75
# Segundo quartil (Q2, Mediana): 1100.0
# Terceiro quartil (Q3): 5275.5
# A distância é 736.1037549407115

# %%
munic_acima_q3 = df_estelionato_dp.loc[df_estelionato_dp['estelionato'] > q3]
munic_acima_q3
# Out:
#                      fmun  estelionato
# 67         Rio de Janeiro       459529
# 47                Niterói        38230
# 24        Duque de Caxias        29747
# 49            Nova Iguaçu        28700
# 77            São Gonçalo        28425
# 14  Campos dos Goytacazes        18605
# 81     São João de Meriti        18575
# 36                  Macaé        14653
# 54             Petrópolis        13907
# 8            Belford Roxo        13147
# 91          Volta Redonda        13127
# 11              Cabo Frio        10533
# 66         Rio das Ostras         9124
# 40                 Maricá         8707
# 48          Nova Friburgo         8642
# 85            Teresópolis         8049
# 46              Nilópolis         7656
# 38                   Magé         7342
# 28               Itaboraí         7185
# 62                Resende         6897
# 2                Araruama         6133
# 0          Angra dos Reis         6078
# 42               Mesquita         5799

# %%
munic_acima_q1 = df_estelionato_dp.loc[df_estelionato_dp['estelionato'] < q1]
munic_acima_q1
# Out:
#                              fmun  estelionato
# 79  São José do Vale do Rio Preto          365
# 64                      Rio Claro          364
# 57                    Porciúncula          356
# 45                     Natividade          338
# 23                    Duas Barras          299
# 13                        Cambuci          293
# 25    Engenheiro Paulo de Frontin          290
# 74                      Sumidouro          270
# 65                 Rio das Flores          219
# 30                         Italva          217
# 59                         Quatis          216
# 3                           Areal          213
# 68           Santa Maria Madalena          192
# 17                Cardoso Moreira          185
# 37                         Macuco          143
# 86              Trajano de Moraes          139
# 1                         Aperibé          134
# 20      Comendador Levy Gasparian          128
# 35                 Laje do Muriaé          126
# 16                      Carapebus          124
# 89                      Varre-Sai          102
# 83          São Sebastião do Alto          100
# 78                São José de Ubá           60

# %%
df_aaapai_dp = dfM.groupby('fmun')['aaapai'].sum().reset_index()
df_aaapai_dp =  df_aaapai_dp.sort_values(by='aaapai', ascending=False)
df_aaapai_dp
# Out:
#                      fmun  aaapai
# 67         Rio de Janeiro   29142
# 77            São Gonçalo    4154
# 14  Campos dos Goytacazes    3377
# 24        Duque de Caxias    3017
# 47                Niterói    2722
# ..                    ...     ...
# 37                 Macuco       7
# 3                   Areal       5
# 65         Rio das Flores       5
# 89              Varre-Sai       5
# 83  São Sebastião do Alto       2
#
# [92 rows x 2 columns]

# %%
array_df_aaapai_dp = np.array(df_aaapai_dp['aaapai'])

# %%
media = np.mean(array_df_aaapai_dp)
mediana = np.median(array_df_aaapai_dp)
q1 = np.quantile(array_df_aaapai_dp, 0.25)
q2 = np.quantile(array_df_aaapai_dp, 0.50)
q3 = np.quantile(array_df_aaapai_dp, 0.75)

print("A média é " +str(media))
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
#Distância = (média - mediana) / mediana
distancia = ((media - mediana)/mediana)
distanciaDEC = (distancia)*100
print(f"A distância é {distanciaDEC}")
# Out:
# A média é 832.8152173913044
# A mediana é 193.5
# Primeiro quartil (Q1): 39.0
# Segundo quartil (Q2, Mediana): 193.5
# Terceiro quartil (Q3): 705.75
# A distância é 330.3954611841366

# %%
municaaapai_acima_q3 = df_aaapai_dp.loc[df_aaapai_dp['aaapai'] > q3]
municaaapai_acima_q3
# Out:
#                      fmun  aaapai
# 67         Rio de Janeiro   29142
# 77            São Gonçalo    4154
# 14  Campos dos Goytacazes    3377
# 24        Duque de Caxias    3017
# 47                Niterói    2722
# 49            Nova Iguaçu    2560
# 11              Cabo Frio    2503
# 81     São João de Meriti    2101
# 91          Volta Redonda    1647
# 48          Nova Friburgo    1566
# 8            Belford Roxo    1563
# 54             Petrópolis    1505
# 28               Itaboraí    1342
# 36                  Macaé    1294
# 66         Rio das Ostras    1175
# 85            Teresópolis    1091
# 62                Resende    1082
# 6             Barra Mansa     999
# 38                   Magé     830
# 0          Angra dos Reis     806
# 42               Mesquita     773
# 2                Araruama     766
# 87              Três Rios     759

# %%
municaaapai_acima_q1 = df_aaapai_dp.loc[df_aaapai_dp['aaapai'] < q1]
municaaapai_acima_q1
# Out:
#                              fmun  aaapai
# 70                       Sapucaia      36
# 13                        Cambuci      28
# 23                    Duas Barras      27
# 64                      Rio Claro      26
# 53                Paty do Alferes      22
# 17                Cardoso Moreira      21
# 16                      Carapebus      21
# 25    Engenheiro Paulo de Frontin      21
# 20      Comendador Levy Gasparian      21
# 30                         Italva      20
# 45                     Natividade      19
# 1                         Aperibé      18
# 79  São José do Vale do Rio Preto      15
# 74                      Sumidouro      12
# 68           Santa Maria Madalena       9
# 35                 Laje do Muriaé       9
# 86              Trajano de Moraes       8
# 78                São José de Ubá       7
# 37                         Macuco       7
# 3                           Areal       5
# 65                 Rio das Flores       5
# 89                      Varre-Sai       5
# 83          São Sebastião do Alto       2

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding='latin1')
df
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36898   159   10  2025  2025m10    35     4  Cachoeiras de Macacu  3300803
# 36899   165   10  2025  2025m10    33     5           Mangaratiba  3302601
# 36900   166   10  2025  2025m10    33     5        Angra dos Reis  3300100
# 36901   167   10  2025  2025m10    43     5                Paraty  3303807
# 36902   168   10  2025  2025m10    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...   NaN   NaN      21                      2
# 1       Capital           3  ...   NaN   NaN      15                      6
# 2       Capital           3  ...   NaN   NaN      47                      2
# 3       Capital           6  ...   NaN   NaN      26                      2
# 4       Capital           4  ...   NaN   NaN      10                      1
# ...         ...         ...  ...   ...   ...     ...                    ...
# 36898  Interior           1  ...   4.0   0.0      37                      2
# 36899  Interior           1  ...   4.0   0.0      21                      0
# 36900  Interior           3  ...  12.0   0.0      82                      8
# 36901  Interior           1  ...   2.0   1.0      11                      1
# 36902  Interior           0  ...   0.0   0.0       3                      1
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 36898                 0                0                          0
# 36899                 0                0                          0
# 36900                 0                1                          0
# 36901                 0                0                          0
# 36902                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 36898                      0                   163     2
# 36899                      0                   196     2
# 36900                      0                   682     2
# 36901                      0                   195     2
# 36902                      0                    66     2
#
# [36903 rows x 63 columns]

# %%
df_capital = df.loc[df['munic'] == "Rio de Janeiro"]
df_capital['veiculo'] = df_capital['furto_veiculos'] + df_capital['roubo_veiculo']
df_capital
# Out:
# C:\Users\celso.gomes\AppData\Local\Temp\ipykernel_24156\2848171153.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_capital['veiculo'] = df_capital['furto_veiculos'] + df_capital['roubo_veiculo']
#        cisp  mes   ano  mes_ano  aisp  risp           munic    mcirc   regiao  \
# 0         1    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 1         4    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 2         5    1  2003  2003m01     5     1  Rio de Janeiro  3304557  Capital
# 3         6    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# 4         7    1  2003  2003m01     1     1  Rio de Janeiro  3304557  Capital
# ...     ...  ...   ...      ...   ...   ...             ...      ...      ...
# 36802    40   10  2025  2025m10     9     2  Rio de Janeiro  3304557  Capital
# 36803    41   10  2025  2025m10    18     2  Rio de Janeiro  3304557  Capital
# 36804    42   10  2025  2025m10    31     2  Rio de Janeiro  3304557  Capital
# 36805    43   10  2025  2025m10    27     2  Rio de Janeiro  3304557  Capital
# 36806    44   10  2025  2025m10     3     1  Rio de Janeiro  3304557  Capital
#
#        hom_doloso  ...  cmba  ameaca  pessoas_desaparecidas  encontro_cadaver  \
# 0               0  ...   NaN      21                      2                 0
# 1               3  ...   NaN      15                      6                 0
# 2               3  ...   NaN      47                      2                 1
# 3               6  ...   NaN      26                      2                 1
# 4               4  ...   NaN      10                      1                 3
# ...           ...  ...   ...     ...                    ...               ...
# 36802           4  ...   0.0      25                      5                 1
# 36803           0  ...   0.0      49                      0                 0
# 36804           3  ...   2.0     102                      6                 3
# 36805           2  ...   1.0     110                     13                 1
# 36806           1  ...   1.0      32                      6                 0
#
#        encontro_ossada  pol_militares_mortos_serv  pol_civis_mortos_serv  \
# 0                    0                          0                      0
# 1                    1                          0                      0
# 2                    0                          0                      0
# 3                    0                          0                      0
# 4                    0                          0                      0
# ...                ...                        ...                    ...
# 36802                0                          0                      0
# 36803                0                          0                      0
# 36804                0                          0                      0
# 36805                0                          0                      0
# 36806                0                          0                      0
#
#        registro_ocorrencias  fase  veiculo
# 0                       578     3       17
# 1                       441     3       18
# 2                       637     3       39
# 3                       473     3       44
# 4                       147     3       35
# ...                     ...   ...      ...
# 36802                   628     2       69
# 36803                   856     2       35
# 36804                  1450     2       79
# 36805                   691     2       22
# 36806                   776     2       45
#
# [11074 rows x 64 columns]

# %%
df_veiculo_capital = df_capital.groupby('cisp')['veiculo'].sum().reset_index()
df_veiculo_capital = df_veiculo_capital.sort_values(by='veiculo', ascending=False)
df_veiculo_capital
# Out:
#     cisp  veiculo
# 23    27    39024
# 30    34    36897
# 31    35    33436
# 35    39    32500
# 34    38    25999
# 29    33    25899
# 17    21    25267
# 18    22    22896
# 36    40    22451
# 25    29    21722
# 12    16    18151
# 26    30    17822
# 27    31    17650
# 40    44    17163
# 19    23    15245
# 20    24    14626
# 24    28    14437
# 28    32    13884
# 16    20    13238
# 33    37    12938
# 5      9    12705
# 21    25    12697
# 13    17    11250
# 14    18    11239
# 22    26    10398
# 15    19    10180
# 37    41    10175
# 38    42    10108
# 32    36    10077
# 6     10     9669
# 3      6     6777
# 39    43     4428
# 2      5     4343
# 4      7     3941
# 10    14     3506
# 1      4     3402
# 11    15     3083
# 0      1     2494
# 8     12     2408
# 9     13     1488
# 7     11      181
# 41    45       78

# %%
array_df_veiculo_capital = np.array(df_veiculo_capital['veiculo'])

# %%
media = np.mean(array_df_veiculo_capital)
mediana = np.median(array_df_veiculo_capital)
q1 = np.quantile(array_df_veiculo_capital, 0.25)
q2 = np.quantile(array_df_veiculo_capital, 0.50)
q3 = np.quantile(array_df_veiculo_capital, 0.75)
#Distância = (média - mediana) / mediana
distancia = ((media - mediana)/mediana)
distanciaDEC = (distancia)*100
iqr = q3 - q1
limite_superior = q3 + 1.5 * iqr
limite_inferior = q1 - 1.5 * iqr

print("A média é " +str(media))
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')

print(f"A distância é {distanciaDEC}")
print(f'O IQR é {iqr}')
print(f'O limite superior é {limite_superior}')
print(f'O limite inferior é {limite_inferior}') 
# quando o limite inferior for negativo, considerar como nao tendo outlier inferior
# Out:
# A média é 13949.333333333334
# A mediana é 12701.0
# Primeiro quartil (Q1): 5015.25
# Segundo quartil (Q2, Mediana): 12701.0
# Terceiro quartil (Q3): 18068.75
# A distância é 9.8286224181823
# O IQR é 13053.5
# O limite superior é 37649.0
# O limite inferior é -14565.0

# %%
outliers_df_veiculo_capital = df_veiculo_capital.loc[(df_veiculo_capital['veiculo'] > limite_superior) | (df_veiculo_capital['veiculo'] < limite_inferior)]
outliers_df_veiculo_capital
# Out:
#     cisp  veiculo
# 23    27    39024

# %%
df = pd.read_csv('https://www.ispdados.rj.gov.br/Arquivos/BaseDPEvolucaoMensalCisp.csv', sep= ';', encoding='latin1')
df
# Out:
#        cisp  mes   ano  mes_ano  aisp  risp                 munic    mcirc  \
# 0         1    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 1         4    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 2         5    1  2003  2003m01     5     1        Rio de Janeiro  3304557
# 3         6    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# 4         7    1  2003  2003m01     1     1        Rio de Janeiro  3304557
# ...     ...  ...   ...      ...   ...   ...                   ...      ...
# 36898   159   10  2025  2025m10    35     4  Cachoeiras de Macacu  3300803
# 36899   165   10  2025  2025m10    33     5           Mangaratiba  3302601
# 36900   166   10  2025  2025m10    33     5        Angra dos Reis  3300100
# 36901   167   10  2025  2025m10    43     5                Paraty  3303807
# 36902   168   10  2025  2025m10    28     5             Rio Claro  3304409
#
#          regiao  hom_doloso  ...   cmp  cmba  ameaca  pessoas_desaparecidas  \
# 0       Capital           0  ...   NaN   NaN      21                      2
# 1       Capital           3  ...   NaN   NaN      15                      6
# 2       Capital           3  ...   NaN   NaN      47                      2
# 3       Capital           6  ...   NaN   NaN      26                      2
# 4       Capital           4  ...   NaN   NaN      10                      1
# ...         ...         ...  ...   ...   ...     ...                    ...
# 36898  Interior           1  ...   4.0   0.0      37                      2
# 36899  Interior           1  ...   4.0   0.0      21                      0
# 36900  Interior           3  ...  12.0   0.0      82                      8
# 36901  Interior           1  ...   2.0   1.0      11                      1
# 36902  Interior           0  ...   0.0   0.0       3                      1
#
#        encontro_cadaver  encontro_ossada  pol_militares_mortos_serv  \
# 0                     0                0                          0
# 1                     0                1                          0
# 2                     1                0                          0
# 3                     1                0                          0
# 4                     3                0                          0
# ...                 ...              ...                        ...
# 36898                 0                0                          0
# 36899                 0                0                          0
# 36900                 0                1                          0
# 36901                 0                0                          0
# 36902                 0                0                          0
#
#        pol_civis_mortos_serv  registro_ocorrencias  fase
# 0                          0                   578     3
# 1                          0                   441     3
# 2                          0                   637     3
# 3                          0                   473     3
# 4                          0                   147     3
# ...                      ...                   ...   ...
# 36898                      0                   163     2
# 36899                      0                   196     2
# 36900                      0                   682     2
# 36901                      0                   195     2
# 36902                      0                    66     2
#
# [36903 rows x 63 columns]

# %%
rj_nit=[lista dos municipios....]
#criar uma lista dos municipios

# %%
df_capital = df.loc[df['munic'] == "Rio de Janeiro"]
df_capital=df.loc[df['munic'].isin[rj_nit]]
df_capital['veiculo'] = df_capital['furto_veiculos'] + df_capital['roubo_veiculo']
df_capital
