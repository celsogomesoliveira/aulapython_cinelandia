# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('pesquisa_satisfacao.csv', sep= ';')
(df)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df= pd.read_csv('pesquisa_satisfacao.xlsx', sep= ';')
#       2 (df)
#       3 df.head(3)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:574, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:663, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2053, in pandas._libs.parsers.raise_parser_error()
#
# File <frozen codecs>:325, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x90 in position 22: invalid start byte

# %%
media_satisfacao = df.groupby('Satisfação')['Tempo de Espera(min)'].mean().resert_index()
media_satisfacao['Tempo de Espera(min)']=round(media_satisfacao['Tempo de Espera (min)'])
media_satisfacao
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26768\1805187401.py in ?()
# ----> 1 media_satisfacao = df.groupby('Satisfação')['Tempo de Espera (min)'].mean().resert_index()
#       2 media_satisfacao['Tempo de Espera(min)']=round(media_satisfacao['Tempo de Espera (min)'])
#       3 media_satisfacao
#
# ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'resert_index'

# %%
df_anp=pd.read_csv('ca-2005-01.csv', sep=';')
df_anp
# Out:
#        Regiao - Sigla Estado - Sigla                    Municipio  \
# 0                  SE             SP                    GUARULHOS
# 1                  SE             SP                    GUARULHOS
# 2                  SE             SP                    GUARULHOS
# 3                  SE             SP                     SOROCABA
# 4                  SE             SP                     SOROCABA
# ...               ...            ...                          ...
# 912724             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912725             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912726             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912727             NE             BA  LIVRAMENTO DE NOSSA SENHORA
# 912728             NE             BA  LIVRAMENTO DE NOSSA SENHORA
#
#                                                   Revenda  \
# 0                                AUTO POSTO SAKAMOTO LTDA
# 1                                AUTO POSTO SAKAMOTO LTDA
# 2                                AUTO POSTO SAKAMOTO LTDA
# 3       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# 4       COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...
# ...                                                   ...
# 912724                      AUTO POSTO PIRES PEREIRA LTDA
# 912725                      AUTO POSTO PIRES PEREIRA LTDA
# 912726                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912727                     AUTO POSTO 5 DE FEVEREIRO LTDA
# 912728                     AUTO POSTO 5 DE FEVEREIRO LTDA
#
#             CNPJ da Revenda                     Nome da Rua Numero Rua  \
# 0        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 1        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 2        49.051.667/0001-02        RODOVIA PRESIDENTE DUTRA        S/N
# 3        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# 4        00.003.188/0001-21          RUA HUMBERTO DE CAMPOS        306
# ...                     ...                             ...        ...
# 912724   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912725   02.253.236/0001-65      AVENIDA LINDEMBERG CARDOSO        667
# 912726   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912727   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
# 912728   02.125.226/0001-44  PRACA CORONEL ZEZINHO TANAJURA          1
#
#                 Complemento          Bairro        Cep   Produto  \
# 0       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580  GASOLINA
# 1       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    ETANOL
# 2       KM 210,5-SENT SP/RJ      BONSUCESSO  07178-580    DIESEL
# 3                       NaN  JARDIM ZULMIRA  18061-000  GASOLINA
# 4                       NaN  JARDIM ZULMIRA  18061-000    ETANOL
# ...                     ...             ...        ...       ...
# 912724               COMODO         TAQUARI  46140-000    ETANOL
# 912725               COMODO         TAQUARI  46140-000    DIESEL
# 912726               COMODO          CENTRO  46140-000  GASOLINA
# 912727               COMODO          CENTRO  46140-000    ETANOL
# 912728               COMODO          CENTRO  46140-000    DIESEL
#
#        Data da Coleta Valor de Venda Valor de Compra Unidade de Medida  \
# 0          04/01/2005          2,257          1,9594        R$ / litro
# 1          04/01/2005          1,449          1,0962        R$ / litro
# 2          04/01/2005          1,579          1,4444        R$ / litro
# 3          04/01/2005           2,21            1,97        R$ / litro
# 4          04/01/2005           1,23            0,93        R$ / litro
# ...               ...            ...             ...               ...
# 912724     27/06/2005           1,98             NaN        R$ / litro
# 912725     27/06/2005           1,69             NaN        R$ / litro
# 912726     27/06/2005            2,5             NaN        R$ / litro
# 912727     27/06/2005           1,95             NaN        R$ / litro
# 912728     27/06/2005           1,69             NaN        R$ / litro
#
#                             Bandeira
# 0       PETROBRAS DISTRIBUIDORA S.A.
# 1       PETROBRAS DISTRIBUIDORA S.A.
# 2       PETROBRAS DISTRIBUIDORA S.A.
# 3                             BRANCA
# 4                             BRANCA
# ...                              ...
# 912724                    PETROBAHIA
# 912725                    PETROBAHIA
# 912726                    PETROBAHIA
# 912727                    PETROBAHIA
# 912728                    PETROBAHIA
#
# [912729 rows x 16 columns]

# %%
df_anp_rj = df_anp.loc[df_anp['Estado - Sigla'] == 'RJ']
df_anp_rj.head(5)
# Out:
#    Regiao - Sigla Estado - Sigla Municipio                       Revenda  \
# 12             SE             RJ   NITEROI  PETROBRAS DISTRIBUIDORA S.A.
# 13             SE             RJ   NITEROI  PETROBRAS DISTRIBUIDORA S.A.
# 14             SE             RJ     MACAE  PETROBRAS DISTRIBUIDORA S.A.
# 15             SE             RJ     MACAE  PETROBRAS DISTRIBUIDORA S.A.
# 16             SE             RJ     MACAE  PETROBRAS DISTRIBUIDORA S.A.
#
#         CNPJ da Revenda                      Nome da Rua Numero Rua  \
# 12   34.274.233/0033-81         AVENIDA ROBERTO SILVEIRA        205
# 13   34.274.233/0033-81         AVENIDA ROBERTO SILVEIRA        205
# 14   34.274.233/0052-44  RUA CONSELHEIRO ALMEIDA PEREIRA        303
# 15   34.274.233/0052-44  RUA CONSELHEIRO ALMEIDA PEREIRA        303
# 16   34.274.233/0052-44  RUA CONSELHEIRO ALMEIDA PEREIRA        303
#
#    Complemento          Bairro        Cep   Produto Data da Coleta  \
# 12         NaN          ICARAÍ  24230-151  GASOLINA     04/01/2005
# 13         NaN          ICARAÍ  24230-151    ETANOL     04/01/2005
# 14         NaN  PRAIA CAMPISTA  27923-510  GASOLINA     04/01/2005
# 15         NaN  PRAIA CAMPISTA  27923-510    ETANOL     04/01/2005
# 16         NaN  PRAIA CAMPISTA  27923-510    DIESEL     04/01/2005
#
#    Valor de Venda Valor de Compra Unidade de Medida  \
# 12          2,289             NaN        R$ / litro
# 13          1,599             NaN        R$ / litro
# 14          2,328          2,1136        R$ / litro
# 15          1,687          1,4259        R$ / litro
# 16          1,606          1,4307        R$ / litro
#
#                         Bandeira
# 12  PETROBRAS DISTRIBUIDORA S.A.
# 13  PETROBRAS DISTRIBUIDORA S.A.
# 14  PETROBRAS DISTRIBUIDORA S.A.
# 15  PETROBRAS DISTRIBUIDORA S.A.
# 16  PETROBRAS DISTRIBUIDORA S.A.

# %%
df_anp_rj['Valor de Venda']=df_anp_rj['Valor de Venda'].str.replace(',', '.').astype(float)
# Out:
# C:\Users\celso.gomes\AppData\Local\Temp\ipykernel_26768\2610844079.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_anp_rj['Valor de Venda']=df_anp_rj['Valor de Venda'].str.replace(',', '.').astype(float)

# %%
media_munic_rj=df_anp_rj.groupby('Municipio')['Valor de Venda'].mean().reset_index()
media_munic_rj = media_munic_rj.sort_values(by='Valor de Venda', ascending=False)
media_munic_rj
# Out:
#                       Municipio  Valor de Venda
# 22                       PARATY        2.046755
# 0                ANGRA DOS REIS        2.025708
# 14                  MANGARATIBA        2.023748
# 33              SAO JOSE DE UBA        2.016154
# 16                     MESQUITA        1.960870
# 37                  TERESOPOLIS        1.951446
# 35                    SAQUAREMA        1.935836
# 39                      VALENCA        1.935772
# 34                     SAPUCAIA        1.930971
# 24                   PETROPOLIS        1.929837
# 2            ARMACAO DOS BUZIOS        1.920374
# 19                NOVA FRIBURGO        1.908377
# 38                    TRES RIOS        1.906549
# 15                       MARICA        1.906101
# 21               PARAIBA DO SUL        1.893178
# 12                        MACAE        1.886574
# 11                    ITAPERUNA        1.883456
# 41                VOLTA REDONDA        1.880727
# 1                      ARARUAMA        1.880255
# 23              PATY DO ALFERES        1.870256
# 18                      NITEROI        1.867720
# 40                    VASSOURAS        1.856202
# 13                         MAGE        1.847169
# 25                    QUEIMADOS        1.841286
# 6                     CABO FRIO        1.826392
# 3                BARRA DO PIRAI        1.822731
# 36                   SEROPEDICA        1.817769
# 30  SAO FRANCISCO DE ITABAPOANA        1.817061
# 4                   BARRA MANSA        1.815369
# 26                      RESENDE        1.810762
# 27                   RIO BONITO        1.804962
# 29       SANTO ANTONIO DE PADUA        1.795913
# 17                    NILOPOLIS        1.792817
# 7         CAMPOS DOS GOYTACAZES        1.780938
# 10                      ITAGUAI        1.772167
# 31                  SAO GONCALO        1.760827
# 5                  BELFORD ROXO        1.746792
# 32           SAO JOAO DE MERITI        1.738916
# 28               RIO DE JANEIRO        1.726500
# 20                  NOVA IGUACU        1.710546
# 8               DUQUE DE CAXIAS        1.710019
# 9                      ITABORAI        1.700943

# %%
array_valor_venda=np.array(media_munic_rj['Valor de Venda'])

# %%
media = np.mean(array_valor_venda)
mediana = np.median(array_valor_venda)
q1 = np.quantile(array_valor_venda,0.25)
q2 = np.quantile(array_valor_venda,0.50)
q3 = np.quantile(array_valor_venda,0.75)
print(f'A média é {media}')
print(f'A mediana é {mediana}')
print(f'Primeiro quartil (Q1): {q1}')
print(f'Segundo quartil (Q2, Mediana): {q2}')
print(f'Terceiro quartil (Q3): {q3}')
# Out:
# A média é 1.858493924321496
# A mediana é 1.8619606638132185
# Primeiro quartil (Q1): 1.7981754885377697
# Segundo quartil (Q2, Mediana): 1.8619606638132185
# Terceiro quartil (Q3): 1.9173751159644377

# %%
munic_acima_q3 = media_munic_rj.loc[media_munic_rj['Valor de Venda']>q3] 
munic_acima_q3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 munic_acima_q3 = media_munic_rj.loc[media_munic_rj['Valor de Venda']>q3]
#       2 munic_acima_q3
#
# NameError: name 'media_munic_rj' is not defined

# %%
df_rj_etanol = df_anp.loc[(df_anp['Municipio'] == 'RIO DE JANEIRO') & (df_anp['Produto'] == 'ETANOL')]
df_rj_etanol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_rj_etanol = df_anp.loc[(df_anp['Municipio'] == 'RIO DE JANEIRO') & (df_anp['Produto'] == 'ETANOL')]
#       2 df_rj_etanol
#
# NameError: name 'df_anp' is not defined
